# %% [markdown]
# # Conclusion

# %% [markdown]
# We will compare the 3 models to see which one is the best.

# %% [markdown]
# ## Random forest
#
# True Negative (TN) : 98
# False Positive (FP): 7
# False Negative (FN): 13
# True Positive (TP) : 61
# Sensitivity or TPR: 82%
# Specificity or TNR: 93%
# Precision: 90%
# Negative Predictive Value: 88%
# False Positive Rate: 7%
# False Negative Rate: 18%
# False Discovery Rate: 10%
# Accuracy: 89%
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## PyCaret
# Model: K Neighbors Classifier
# Accuracy: 79%
# AUC: 80%
# Recall: 54%
# Prec.: 85%
# F1: 66%
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## SageMaker
# Sensitivity (Recall): 73.53%
# Specificity: 70.91%
# Precision: 60.98%
# Negative Predictive Value (NPV): 81.25%
# False Positive Rate (FPR): 29.09%
# False Negative Rate (FNR): 26.47%
# False Discovery Rate (FDR): 39.02%
# Accuracy: 71.91%
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# We can conclude that the random forest classifier is the best model with an accuracy of 89% and an auc of 96%.
