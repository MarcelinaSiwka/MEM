# %% [markdown]
# # Conclusion
# ### Compared the 3 models to see which one is the best.

# %% [markdown]
# ### LinearRegression

# %% [markdown]
# ##### Cross-Validation Scores for Linear Regression: [0.16025004 0.15931688 0.15930747 0.15930961 0.15647123]
# ##### Average Cross-Validation Score: 0.15893104611405173

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### GradientBoostingRegressor

# %% [markdown]
# ##### Training R^2 Score: 0.4551342035110042
# ##### Testing R^2 Score: 0.4570984693928256
# ##### Training RMSE: 88973.85966566954
# ##### Testing RMSE: 88884.30975039733

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### DecisionTreeRegressor

# %% [markdown]
# #### Best Parameters: {'min_samples_split': 10, 'min_samples_leaf': 20, 'max_features': None, 'max_depth': None}
# #### Best Cross-Validation R^2 Score: 0.6189309890812591
# #### Cross-Validation R^2 Scores for Best Model: [0.61881607 0.61903991 0.62033254 0.61524092 0.62122551]
# #### Average R^2 Score for Best Model: 0.6189309890812591

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### As we can see the only good performing model on this dataset is Decision Tree Regressor with Best Cross-Validation R^2 Score of 61%
